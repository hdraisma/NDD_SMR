# %% [markdown]
# # SMR
# - Based on SMR_template.txt
# - run updated v8 GTEx on all Summary Statistics (including new BD summary statistics)
# - automate swarm creation

# %%
#REF first two 'hits' upon googling for "where should i install modules for use with jupyter notebook" as at 2023-11-22 15:27GMT (HD):
#
#!pip install pandas   #<-- Commented this line as at 2023-11-23 20:50GMT (HD).

# %%
import zipfile
import pandas as pd
import os
import glob
import numpy as np
import scipy
from scipy.stats import norm
import sys
import subprocess

# %%
def shell_do(command, log=False, return_log=False, make_part=False):
    print(f'Executing: {(" ").join(command.split())}', file=sys.stderr)

    if make_part == False:
        res = subprocess.run(command.split(), stdout=subprocess.PIPE)
    else:
        res = subprocess.run(command, shell=True, stdout=subprocess.PIPE)

# %%
def SMR(disease, stats_path, work_dir, out_dir):
    ### START Code temporarily(?) commented as at 2023-12-19 10:35GMT (HD).
    #
    #
    #
    #
    ##with open(f'.../omicSynth/v8/swarms/{disease}.SMR_swarm', 'w') as f:   #<-- Commented this line as at 2023-11-23 20:28GMT (HD).
    ##
    ##v Line below 'new' code as at 2023-11-23 20:28GMT (HD). v
    #with open(f'/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/v8/swarms/{disease}.SMR_swarm', 'w') as f:
    #    #
    #    #
    #    #f.write('cd .../omicSynth/v8/intermediate_results/ \n')   #<-- Commented this line as at 2023-11-23 20:23GMT (HD).
    #    #
    #    f.write('cd "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/v8/intermediate_results/" \n')   #<-- This line 'new' code as at 2023-11-23 20:32GMT (HD).
    #    #
    #    #
    #    #
    #    #
    ### END Code temporarily(?) commented as at 2023-12-19 10:35GMT (HD).
    #
    #
    #
    ### START 'new' code as at 2023-12-19 10:33GMT (HD)
    #
    #
    cmd = f'cd "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/v8/intermediate_results/"'
    
    shell_do(cmd, make_part=True)
    #
    #
    ### END 'new' code as at 2023-12-19 10:33GMT (HD).
    #
    #
    #
    ### START Code temporarily(?) commented as at 2023-12-19 10:37GMT (HD).
    #
    #
    #
    #
    #f.write('module load SMR \n')
    #f.write('\n')
    #f.write('\n')
    #f.write('# Single file per assay starts here. \n')
    #f.write('\n')
    #f.write('## expression_blood_eQTLgen ## \n')
    #f.write(f'smr --gwas-summary {stats_path} --beqtl-summary {work_dir}/SMR_omics/eQTLs/eQTLgen/cis-eQTLs-full_eQTLGen_AF_incl_nr_formatted_20191212.new.txt_besd-dense --ld-upper-limit --out {out_dir}/{disease}_expression_blood_eQTLgen_SMR_allChrs --bfile .../omicSynth/additional_reference_data/1KG_and_refFlats/1kgenomes/1kg_eur_1pct_ref_panel --smr-multi \n')
    #f.write(' \n')
    #f.write('## expression_brain_eMeta ## \n')
    ##
    ##
    ##f.write(f'smr --gwas-summary {stats_path} --beqtl-summary {work_dir}/SMR_omics/eQTLs/Brain-eMeta/Brain-eMeta --ld-upper-limit --out {out_dir}/{disease}_expression_brain_eMeta_SMR_allChrs --bfile .../omicSynth/additional_reference_data/1KG_and_refFlats/1kgenomes/1kg_eur_1pct_ref_panel --smr-multi \n')   #<-- Commented this line as at 2023-11-23 20:35GMT (HD), and uncommented again as at 2023-12-14 13:43GMT (HD):, and commented again as at 2023-12-19 09:51GMT (HD).
    ##Googling for "brain-emeta" yielded as one of the 'hits' "https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8053199/":
    ##====
    ##In addition, we repeated the analysis by using the meta-analyzed version of the eQTL summary data (named brain-eMeta hereafter), which included results from the GTEx data of brain tissues22, the Common Mind Consortium23, and the Religious Orders Study and the Rush Memory and Aging Project24. Results from these three studies were meta-analyzed using the MeCS method (meta-analysis of cis-eQTL in correlated samples) to increase the power of detecting brain eQTLs25. Only SNPs within 1 Mb distance from each individual probe are available. The eQTL data can be downloaded at https://cnsgenomics.com/data/SMR/#eQTLsummarydata
    ##====
    ##==> "https://cnsgenomics.com/data/SMR/#eQTLsummarydata" includes "	Brain-eMeta.tar.gz" (== "https://cnsgenomics.com/data/SMR/Brain-eMeta.tar.gz"), so could continue with downloading that and using *that* as a (proper?) reference for "Brain-eMeta"???? (!!)
    ##HOWEVER, also, "https://yanglab.westlake.edu.cn/software/smr/#DataResource" mentions that:
    ##====
    ##Brain-eMeta ([* -- HD for emphasis]now called BrainMeta v1[* -- HD end for emphasis]) eQTL data (estimated effective n = 1194)
    ##
    ##BrarinMeta[sic -- HD] eQTL summary data (Qi et al. 2018 Nat Commun) in SMR binary (BESD) format: BrainMeta_v1.tar.gz (1.1 GB)
    ##
    ##This is a set of eQTL data from a meta-analysis of GTEx brain (GTEx Consortium 2017 Nature), CMC (Fromer et al. 2016 Nat Neurosci), and ROSMAP (Ng et al. 2017 Nat Neurosci) by MeCS. Only SNPs within 1Mb distance from each probe are available.
    ##====
    ##... so "BrainMeta[ v1]" should actually equate to "Brain-eMeta"... grmbl i.e. not necessarily making matters easier IMHO 'but OK'.
    ##
    ##f.write(f'smr --gwas-summary {stats_path} --beqtl-summary {work_dir}/SMR_omics/eQTLs/Brain-eMeta/Brain-eMeta --ld-upper-limit --out {out_dir}/{disease}_expression_brain_eMeta_SMR_allChrs --bfile "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/additional_reference_data/1KG_and_refFlats/1kgenomes/1kg_eur_1pct_ref_panel" --smr-multi \n')   #<-- This line 'new' code as at 2023-11-24 21:21GMT (HD) -- + NOTE: *ASSUMING* that Alvarado et al. medRxiv-2023 considered *cis*-eQTLs to be Brain-eMeta eQTLs: REF "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/SMR_omics/eQTLs/Brain-eMeta/Brain-eMeta" (i.e. a symbolic link to a directory holding "BrainMeta_cis_eqtl_summary" data [sic], as downloaded from "https://yanglab.westlake.edu.cn/data/SMR"). #Commented this line as at 2023-12-11 16:55GMT (HD), as I obtained the below ERROR:
    ##====
    ##(base) hammie@hammie-Default-string:/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/pd_smr$ smr-1.3.1 --gwas-summary '/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/pd_smr/nallsEtAl2019_excluding23andMe_allVariants_mygwasDOTmaFormatFieldsOnly.tab' --beqtl-summary "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/SMR_omics/eQTLs/Brain-eMeta/Brain-eMeta" --out "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/v8/inter_test/PD_expression_brain_eMeta_SMR_allChrs" --bfile "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/additional_reference_data/1KG_and_refFlats/1kgenomes/1kg_eur_1pct_ref_panel" --smr-multi
    ##*******************************************************************
    ##* Summary-data-based Mendelian Randomization (SMR)
    ##* Version 1.3.1
    ##* Build at Sep 21 2022 12:13:19, by GCC 8.3
    ##* (C) 2015 Futao Zhang, Zhihong Zhu and Jian Yang
    ##* The University of Queensland
    ##* MIT License
    ##*******************************************************************
    ##Analysis started: 16:29:13,Mon Dec 11,2023
    ##
    ##Options:
    ##--gwas-summary /media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/pd_smr/nallsEtAl2019_excluding23andMe_allVariants_mygwasDOTmaFormatFieldsOnly.tab
    ##--beqtl-summary /media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/SMR_omics/eQTLs/Brain-eMeta/Brain-eMeta
    ##--out /media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/v8/inter_test/PD_expression_brain_eMeta_SMR_allChrs
    ##--bfile /media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/additional_reference_data/1KG_and_refFlats/1kgenomes/1kg_eur_1pct_ref_panel
    ##--smr-multi 
    ##
    ##Reading GWAS summary data from [/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/pd_smr/nallsEtAl2019_excluding23andMe_allVariants_mygwasDOTmaFormatFieldsOnly.tab].
    ##GWAS summary data of 17510617 SNPs to be included from [/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/pd_smr/nallsEtAl2019_excluding23andMe_allVariants_mygwasDOTmaFormatFieldsOnly.tab].
    ##
    ##ERROR: can not open the file [/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/SMR_omics/eQTLs/Brain-eMeta/Brain-eMeta.esi] to read.
    ##
    ##Analysis completed: 16:29:58,Mon Dec 11,2023
    ##Computational time: 0:0:45
    ##(base) hammie@hammie-Default-string:/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/pd_smr$ pwd
    ##/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/pd_smr
    ##(base) hammie@hammie-Default-string:/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/pd_smr$
    ##====
    ##
    ##f.write(f'smr --gwas-summary {stats_path} --beqtl-summary /home/hammie/DATA/SMR/BrainMeta_cis_eqtl_summary/BrainMeta_cis_eQTL_chr1 --ld-upper-limit --out {out_dir}/{disease}_expression_brain_eMeta_SMR_allChrs --bfile "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/additional_reference_data/1KG_and_refFlats/1kgenomes/1kg_eur_1pct_ref_panel" --smr-multi \n')   #<-- This line 'new' code as at 2023-12-11 17:02GMT (HD) -- + NOTE: *ASSUMING* that Alvarado et al. medRxiv-2023 considered *cis*-eQTLs to be Brain-eMeta eQTLs: REF "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/SMR_omics/eQTLs/Brain-eMeta/Brain-eMeta" (i.e. a symbolic link to a directory holding "BrainMeta_cis_eqtl_summary" data [sic], as downloaded from "https://yanglab.westlake.edu.cn/data/SMR"). #Commented this line as at 2023-12-11 17:22GMT (HD), as its execution yielded the following ERROR:
    ##====
    ##(base) hammie@hammie-Default-string:/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/pd_smr$ smr-1.3.1 --gwas-summary '/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/pd_smr/nallsEtAl2019_excluding23andMe_allVariants_mygwasDOTmaFormatFieldsOnly.tab' --beqtl-summary /home/hammie/DATA/SMR/BrainMeta_cis_eqtl_summary/BrainMeta_cis_eQTL_chr1 --out "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/v8/inter_test/PD_expression_brain_eMeta_SMR_allChrs" --bfile "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/additional_reference_data/1KG_and_refFlats/1kgenomes/1kg_eur_1pct_ref_panel" --smr-multi
    ##*******************************************************************
    ##* Summary-data-based Mendelian Randomization (SMR)
    ##* Version 1.3.1
    ##* Build at Sep 21 2022 12:13:19, by GCC 8.3
    ##* (C) 2015 Futao Zhang, Zhihong Zhu and Jian Yang
    ##* The University of Queensland
    ##* MIT License
    ##*******************************************************************
    ##Analysis started: 17:6:34,Mon Dec 11,2023
    ##
    ##Options:
    ##--gwas-summary /media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/pd_smr/nallsEtAl2019_excluding23andMe_allVariants_mygwasDOTmaFormatFieldsOnly.tab
    ##--beqtl-summary /home/hammie/DATA/SMR/BrainMeta_cis_eqtl_summary/BrainMeta_cis_eQTL_chr1
    ##--out /media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/v8/inter_test/PD_expression_brain_eMeta_SMR_allChrs
    ##--bfile /media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/additional_reference_data/1KG_and_refFlats/1kgenomes/1kg_eur_1pct_ref_panel
    ##--smr-multi 
    ##
    ##Reading GWAS summary data from [/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/pd_smr/nallsEtAl2019_excluding23andMe_allVariants_mygwasDOTmaFormatFieldsOnly.tab].
    ##GWAS summary data of 17510617 SNPs to be included from [/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/pd_smr/nallsEtAl2019_excluding23andMe_allVariants_mygwasDOTmaFormatFieldsOnly.tab].
    ##Reading eQTL SNP information from [/home/hammie/DATA/SMR/BrainMeta_cis_eqtl_summary/BrainMeta_cis_eQTL_chr1.esi].
    ##920092 SNPs to be included from [/home/hammie/DATA/SMR/BrainMeta_cis_eqtl_summary/BrainMeta_cis_eQTL_chr1.esi].
    ##
    ##Error: can not open the file [/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/additional_reference_data/1KG_and_refFlats/1kgenomes/1kg_eur_1pct_ref_panel.fam] to read.
    ##
    ##Analysis completed: 17:7:24,Mon Dec 11,2023
    ##(base) hammie@hammie-Default-string:/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/pd_smr(base) hammie@hammie-Default-string:/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/pd_smr$ pwd
    ##/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/pd_smr
    ##(base) hammie@hammie-Default-string:/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/pd_smr$       
    ##====
    ##
    ##f.write(f'smr --gwas-summary {stats_path} --beqtl-summary /home/hammie/DATA/SMR/BrainMeta_cis_eqtl_summary/BrainMeta_cis_eQTL_chr1 --ld-upper-limit --out {out_dir}/{disease}_expression_brain_eMeta_SMR_allChrs --bfile "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/additional_reference_data/1KG_and_refFlats/1kgenomes/EUR" --smr-multi \n')   #<-- This line 'new' code as at 2023-12-11 17:24GMT (HD) -- + NOTE: *ASSUMING* that Alvarado et al. medRxiv-2023 considered *cis*-eQTLs to be Brain-eMeta eQTLs: REF "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/SMR_omics/eQTLs/Brain-eMeta/Brain-eMeta" (i.e. a symbolic link to a directory holding "BrainMeta_cis_eqtl_summary" data [sic], as downloaded from "https://yanglab.westlake.edu.cn/data/SMR"). #Commented this line as at 2023-12-19 09:59GMT (HD).
    ##
    ##
    ##        
    ### END Code temporarily(?) commented as at 2023-12-19 10:37GMT (HD).
    #
    #
    #
    #
    ### START 'new' code as at 2023-12-19 09:57GMT (HD)
    #
    #
    ### START Code commented as at 2023-12-21 12:36GMT (HD), as superfluous by now
    #
    #
    #
    #cmd = f'PATH=$PATH:"/media/hammie/My Passport/SOFTWARE/smr-1.3.1-linux-x86_64"'
    #
    #shell_do(cmd, make_part=True)
    #
    #
    #
    ### END Code commented as at 2023-12-21 12:36GMT (HD).
    #
    #v Note re below: 'only' 22 chromosomes, as per contents of "/home/hammie/DATA/SMR/BrainMeta_cis_eqtl_summary" as on the Brutus as at 2023-12-19 10:04GMT (HD). v
    #
    #v TEMPorarily commented line below, for testing only as at 2023-12-21 11:26GMT (HD). v #Uncommented this line again as at 2023-12-21 12:52GMT (HD).
    #for i in range(1,23):
    #
    #v Line below 'new' and temporary, for testing purposes (i.e., run analysis for CHR 22 *only* -- note that Python's range() function counts up to but not including the second number mentioned) only as at 2023-12-21 11:29GMT (HD). v
    for i in range(22,23):   #<-- Commented this line as at 2023-12-21 12:51GMT (HD).
        #cmd = f'smr --gwas-summary {stats_path} --beqtl-summary /home/hammie/DATA/SMR/BrainMeta_cis_eqtl_summary/BrainMeta_cis_eQTL_chr{i} --ld-upper-limit --out {out_dir}/{disease}_expression_brain_eMeta_SMR_chr{i} --bfile "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/additional_reference_data/1KG_and_refFlats/1kgenomes/EUR" --smr-multi'   #<-- This line 'new' code as at 2023-12-11 17:24GMT (HD) -- + NOTE: *ASSUMING* that Alvarado et al. medRxiv-2023 considered *cis*-eQTLs to be Brain-eMeta eQTLs: REF "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/SMR_omics/eQTLs/Brain-eMeta/Brain-eMeta" (i.e. a symbolic link to a directory holding "BrainMeta_cis_eqtl_summary" data [sic], as downloaded from "https://yanglab.westlake.edu.cn/data/SMR"). #Commented this line as at 2023-12-19 17:53GMT (HD).
        #
        #cmd = f'smr-1.3.1 --gwas-summary {stats_path} --beqtl-summary /home/hammie/DATA/SMR/BrainMeta_cis_eqtl_summary/BrainMeta_cis_eQTL_chr{i} --ld-upper-limit --out {out_dir}/{disease}_expression_brain_eMeta_SMR_chr{i} --bfile "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/additional_reference_data/1KG_and_refFlats/1kgenomes/EUR" --smr-multi'   #<-- This line 'new' code as at 2023-12-11 17:24GMT (HD) -- + NOTE: *ASSUMING* that Alvarado et al. medRxiv-2023 considered *cis*-eQTLs to be Brain-eMeta eQTLs: REF "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/SMR_omics/eQTLs/Brain-eMeta/Brain-eMeta" (i.e. a symbolic link to a directory holding "BrainMeta_cis_eqtl_summary" data [sic], as downloaded from "https://yanglab.westlake.edu.cn/data/SMR"). #This line 'new' code as at 2023-12-19 17:55GMT (HD), as the following worked in an OS terminal on the Brutus: #<-- Commented this line as at 2023-12-19 18:02GMT (HD), as it produced an error even though issuing "$ smr-1.3.1" in an OS terminal on the Brutus worked. #... and uncommented this line again as at 2023-12-19 18:21GMT (HD)., and recommented it again as at 2023-12-19 18:26GMT (HD).
        #====
        #(base) hammie@hammie-Default-string:/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/pd_smr$ smr-1.3.1 --gwas-summary '/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/pd_smr/nallsEtAl2019_excluding23andMe_allVariantsASrsIDs_mygwasDOTmaFormatFieldsOnly.tab' --beqtl-summary /home/hammie/DATA/SMR/BrainMeta_cis_eqtl_summary/BrainMeta_cis_eQTL_chr1 --out "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/v8/inter_test/PD_expression_brain_eMeta_SMR_allChrs" --bfile "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/additional_reference_data/1KG_and_refFlats/1kgenomes/EUR" --smr-multi
        #====
        #
        #cmd = f'PATH=$PATH:"/media/hammie/My Passport/SOFTWARE/smr-1.3.1-linux-x86_64"; smr-1.3.1 --gwas-summary {stats_path} --beqtl-summary /home/hammie/DATA/SMR/BrainMeta_cis_eqtl_summary/BrainMeta_cis_eQTL_chr{i} --ld-upper-limit --out {out_dir}/{disease}_expression_brain_eMeta_SMR_chr{i} --bfile "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/additional_reference_data/1KG_and_refFlats/1kgenomes/EUR" --smr-multi'   #<-- This line 'new' code as at 2023-12-11 17:24GMT (HD) -- + NOTE: *ASSUMING* that Alvarado et al. medRxiv-2023 considered *cis*-eQTLs to be Brain-eMeta eQTLs: REF "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/SMR_omics/eQTLs/Brain-eMeta/Brain-eMeta" (i.e. a symbolic link to a directory holding "BrainMeta_cis_eqtl_summary" data [sic], as downloaded from "https://yanglab.westlake.edu.cn/data/SMR"). #This line 'new' code as at 2023-12-19 18:05GMT (HD) #Commented this line as at 2023-12-19 18:20GMT (HD) -- however, it appears to be necessary as when I issued the "$PATH" amendment only once, as at 2023-12-19 18:23GMT I obtained the following errors: #Commented this line as at 2023-12-21 11:40GMT (HD).
        #====
        #Executing: cd "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/v8/intermediate_results/"
        #Executing: PATH=$PATH:"/media/hammie/My Passport/SOFTWARE/smr-1.3.1-linux-x86_64"
        #Executing: smr-1.3.1 --gwas-summary "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/pd_smr/nallsEtAl2019_excluding23andMe_allVariants_mygwasDOTmaFormatFieldsOnly.tab" --beqtl-summary /home/hammie/DATA/SMR/BrainMeta_cis_eqtl_summary/BrainMeta_cis_eQTL_chr1 --ld-upper-limit --out /media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/v8/inter_test/PD_expression_brain_eMeta_SMR_chr1 --bfile "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/additional_reference_data/1KG_and_refFlats/1kgenomes/EUR" --smr-multi
        #/bin/sh: 1: smr-1.3.1: not found
        #Executing: smr-1.3.1 --gwas-summary "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/pd_smr/nallsEtAl2019_excluding23andMe_allVariants_mygwasDOTmaFormatFieldsOnly.tab" --beqtl-summary /home/hammie/DATA/SMR/BrainMeta_cis_eqtl_summary/BrainMeta_cis_eQTL_chr2 --ld-upper-limit --out /media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/v8/inter_test/PD_expression_brain_eMeta_SMR_chr2 --bfile "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/additional_reference_data/1KG_and_refFlats/1kgenomes/EUR" --smr-multi
        #/bin/sh: 1: smr-1.3.1: not found
        #Executing: smr-1.3.1 --gwas-summary "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/pd_smr/nallsEtAl2019_excluding23andMe_allVariants_mygwasDOTmaFormatFieldsOnly.tab" --beqtl-summary /home/hammie/DATA/SMR/BrainMeta_cis_eqtl_summary/BrainMeta_cis_eQTL_chr3 --ld-upper-limit --out /media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/v8/inter_test/PD_expression_brain_eMeta_SMR_chr3 --bfile "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/additional_reference_data/1KG_and_refFlats/1kgenomes/EUR" --smr-multi
        #/bin/sh: 1: smr-1.3.1: not found
        #[... -- HD]
        #====
        #
        cmd = f'PATH=$PATH:"/media/hammie/My Passport/SOFTWARE/smr-1.3.1-linux-x86_64"; smr-1.3.1 --gwas-summary {stats_path} --beqtl-summary /home/hammie/DATA/SMR/BrainMeta_cis_eqtl_summary/BrainMeta_cis_eQTL_chr{i} --out "{out_dir}/{disease}_expression_brain_eMeta_SMR_chr{i}" --bfile "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/additional_reference_data/1KG_and_refFlats/1kgenomes/EUR" --smr-multi'   #<-- This line 'new' code as at 2023-12-21 11:40GMT (HD), as I had been obtaining the below error:
        #====
        #(base) hammie@hammie-Default-string:/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/pd_smr$ pwd
        #/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/pd_smr
        #(base) hammie@hammie-Default-string:/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/pd_smr$ smr-1.3.1 --gwas-summary "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/pd_smr/nallsEtAl2019_excluding23andMe_allVariants_mygwasDOTmaFormatFieldsOnly.tab" --beqtl-summary /home/hammie/DATA/SMR/BrainMeta_cis_eqtl_summary/BrainMeta_cis_eQTL_chr22 --ld-upper-limit --out "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/v8/inter_test"/PD_expression_brain_eMeta_SMR_chr22TESTONLY --bfile "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/additional_reference_data/1KG_and_refFlats/1kgenomes/EUR" --smr-multi
        #*******************************************************************
        #* Summary-data-based Mendelian Randomization (SMR)
        #* Version 1.3.1
        #* Build at Sep 21 2022 12:13:19, by GCC 8.3
        #* (C) 2015 Futao Zhang, Zhihong Zhu and Jian Yang
        #* The University of Queensland
        #* MIT License
        #*******************************************************************
        #Analysis started: 11:33:17,Thu Dec 21,2023
        #
        #Options:
        #--gwas-summary /media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/pd_smr/nallsEtAl2019_excluding23andMe_allVariants_mygwasDOTmaFormatFieldsOnly.tab
        #--beqtl-summary /home/hammie/DATA/SMR/BrainMeta_cis_eqtl_summary/BrainMeta_cis_eQTL_chr22
        #--ld-upper-limit 0.000000
        #--bfile /media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/additional_reference_data/1KG_and_refFlats/1kgenomes/EUR
        #--smr-multi 
        #
        #ERROR: --ld-min 0.050000 is larger than --ld-top 0.000000.
        #(base) hammie@hammie-Default-string:/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/pd_smr$
        #====
        
        shell_do(cmd, make_part=True)
    #f.write(' \n')        
    #
    #
    ### END 'new' code as at 2023-12-19 09:57GMT (HD).
    #        
    #
    #
    ### START Code temporarily(?) commented as at 2023-12-19 17:14GMT (HD).
    #
    #
    #f.write(' \n')
    #f.write('## methylation_brain_mMeta ## \n')
    #f.write(f'smr --gwas-summary {stats_path} --beqtl-summary {work_dir}/SMR_omics/regQTLs/Brain-mMeta/Brain-mMeta --ld-upper-limit --out {out_dir}/{disease}_methylation_brain_mMeta_SMR_allChrs --bfile .../omicSynth/additional_reference_data/1KG_and_refFlats/1kgenomes/1kg_eur_1pct_ref_panel --smr-multi \n')
    #f.write('## chromatin_blood_Bryois ## \n')
    #f.write(f'smr --gwas-summary {stats_path} --beqtl-summary {work_dir}/SMR_omics/regQTLs/Bryois_caQTLs/bryois_NatCommun_2018_50kb_cQTLs --ld-upper-limit --out {out_dir}/{disease}_chromatin_blood_Bryois_SMR_allChrs --bfile .../omicSynth/additional_reference_data/1KG_and_refFlats/1kgenomes/1kg_eur_1pct_ref_panel --smr-multi \n')
    #f.write(' \n')
    #f.write('# Multi chromosome reference data starts here. \n')
    #f.write(' \n')
    # 
    #f.write('## methylation_blood_mcrae ## \n')
    #for i in range(1,23): 
    #    f.write(f'smr --gwas-summary {stats_path} --beqtl-summary {work_dir}/SMR_omics/regQTLs/Blood-mMeta/bl_mqtl_lite_chr{i} --out {out_dir}/{disease}_methylation_blood_mcrae_SMR_chr{i} --bfile .../omicSynth/additional_reference_data/1KG_and_refFlats/1kgenomes/1kg_eur_1pct_ref_panel --smr-multi \n')
    #f.close()
    #
    ## swarm command
    ##cmd = f'swarm -b 15 -f .../omicSynth/v8/swarms/{disease}.SMR_swarm -g 48 -t 12 --logdir .../omicSynth/v8/swarms --module SMR'   #<-- Commented this line as at 2023-11-23 20:49GMT (HD).
    ##
    #cmd = f'swarm -b 15 -f "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/v8/swarms/{disease}.SMR_swarm" -g 48 -t 12 --logdir "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/v8/swarms" --module SMR'   #<-- This line 'new' code as at 2023-11-23 20:49GMT (HD).
    #
    #shell_do(cmd)
    #
    #
    ### END Code temporarily(?) commented as at 2023-12-19 17:14GMT (HD).

def SMR_meta(disease, stats_path, work_dir, out_dir):
    with open(f'.../omicSynth/v8/swarms/{disease}_meta.SMR_swarm', 'w') as f:
        f.write('cd .../omicSynth/intermediate_results/ \n')
        f.write('module load SMR \n')
        f.write('\n')
        f.write('\n')
        f.write('# Multi chromosome reference data starts here. \n')
        f.write(' \n')
        
        f.write('## expression_basalganglia_metaBrain ## \n')
        for i in range(1,23):
            f.write(f'smr --gwas-summary {stats_path} --beqtl-summary {work_dir}/SMR_omics/eQTLs/2020-05-26-Basalganglia-EUR/2020-05-26-Basalganglia-EUR-{i}-SMR-besd --out {out_dir}/{disease}_expression_Basalganglia_metaBrain_SMR_chr{i} --bfile .../omicSynth/additional_reference_data/1KG_and_refFlats/1kgenomes/1kg_eur_1pct_ref_panel_gr38_metaBrain_variant_names --smr-multi \n')
        f.write(' \n')

        f.write('## expression_cerebellum_metaBrain ## \n')
        for i in range(1,23):
            f.write(f'smr --gwas-summary {stats_path} --beqtl-summary {work_dir}/SMR_omics/eQTLs/2020-05-26-Cerebellum-EUR/2020-05-26-Cerebellum-EUR-{i}-SMR-besd --out {out_dir}/{disease}_expression_Cerebellum_metaBrain_SMR_chr{i} --bfile .../omicSynth/additional_reference_data/1KG_and_refFlats/1kgenomes/1kg_eur_1pct_ref_panel_gr38_metaBrain_variant_names --smr-multi \n')
        f.write(' \n')

        f.write('## expression_cortex_metaBrain ## \n')
        for i in range(1,23):    
            f.write(f'smr --gwas-summary {stats_path} --beqtl-summary {work_dir}/SMR_omics/eQTLs/2020-05-26-Cortex-EUR/2020-05-26-Cortex-EUR-{i}-SMR-besd --out {out_dir}/{disease}_expression_Cortex_metaBrain_SMR_chr{i} --bfile .../omicSynth/additional_reference_data/1KG_and_refFlats/1kgenomes/1kg_eur_1pct_ref_panel_gr38_metaBrain_variant_names --smr-multi \n')
        f.write(' \n')

        f.write('## expression_hippocampus_metaBrain ## \n')
        for i in range(1,23):  
            f.write(f'smr --gwas-summary {stats_path} --beqtl-summary {work_dir}/SMR_omics/eQTLs/2020-05-26-Hippocampus-EUR/2020-05-26-Hippocampus-EUR-{i}-SMR-besd --out {out_dir}/{disease}_expression_Hippocampus_metaBrain_SMR_chr{i} --bfile .../omicSynth/additional_reference_data/1KG_and_refFlats/1kgenomes/1kg_eur_1pct_ref_panel_gr38_metaBrain_variant_names --smr-multi \n')
        f.write(' \n')

        f.write('## expression_spinalchord_metaBrain ## \n')
        for i in range(1,23): 
            f.write(f'smr --gwas-summary {stats_path} --beqtl-summary {work_dir}/SMR_omics/eQTLs/2020-05-26-Spinalcord-EUR/2020-05-26-Spinalcord-EUR-{i}-SMR-besd --out {out_dir}/{disease}_expression_Spinalcord_metaBrain_SMR_chr{i} --bfile .../omicSynth/additional_reference_data/1KG_and_refFlats/1kgenomes/1kg_eur_1pct_ref_panel_gr38_metaBrain_variant_names --smr-multi \n')
        f.write(' \n')
        f.close()
        
    # swarm command
    cmd = f'swarm -b 15 -f .../omicSynth/v8/swarms/{disease}_meta.SMR_swarm -g 48 -t 12 --logdir .../omicSynth/v8/swarms --module SMR'

    shell_do(cmd)

def SMR_gtex(disease, stats_path, work_dir, out_dir, gtex_list):
    ### For this function definition, try and do analogously as for SMR()'s definition above: START Code temporarily(?) commented as at 2023-12-21 17:10GMT (HD).
    #
    #
    #
    #
    #with open(f'.../omicSynth/v8/swarms/{disease}_gtex.SMR_swarm', 'w') as f:
    #    f.write('cd .../micSynth/v8/intermediate_results/ \n')
    #
    #
    #
    #
    ### END Code temporarily(?) commented as at 2023-12-21 17:10GMT (HD).
    #
    #
    #
    ### START code copy--pasted from SMR() function definition above as at 2023-12-21 17:13GMT (HD)
    #
    #
    cmd = f'cd "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/v8/intermediate_results/"'
    
    shell_do(cmd, make_part=True)
    #
    #
    ### END code copy--pasted from SMR() function definition above as at 2023-12-21 17:13GMT (HD).
    #
    #
    #
    ### START Code temporarily(?) commented as at 2023-12-21 17:20GMT (HD).
    #
    #
    #
    #
    #f.write('module load SMR \n')
    #f.write('\n')
    #f.write('\n')
    #f.write('# expression_GTEx \n')
    #f.write(' \n')
    #
    #
    #
    #
    ### END Code temporarily(?) commented as at 2023-12-21 17:20GMT (HD).

    for part in gtex_list:   #<-- TEMPorarily commented this line, for testing purposes only as at 2023-12-22 20:57GMT (HD)
    #
    #v Line below 'new' code, for testing only (this way, would analyses be run for first tissue listed in 'gtexlist' only indeed? <-- A: NO -- as at 2023-12-22 22:25GMT [HD]: i.e. this simply doesn't work) as at 2023-12-22 20:58GMT (HD) v
    #for part in gtex_list[1]:
        #f.write(f'smr --gwas-summary {stats_path} --beqtl-summary .../omicSynth/SMR_omics/eQTLs/GTEx_v8/eQTL_besd_lite/{part} --out {out_dir}/{disease}_expression_{part}_GTEx_SMR_allChrs --bfile .../omicSynth/additional_reference_data/1KG_and_refFlats/1kgenomes/1kg_eur_1pct_ref_panel  --smr-multi \n')   #<-- Commented this line as at 2023-12-21 17:27GMT (HD).
        
        ### START code amended from SMR() function definition above as at 2023-12-21 17:29GMT (HD).
        #
        #
        cmd = f'PATH=$PATH:"/media/hammie/My Passport/SOFTWARE/smr-1.3.1-linux-x86_64"; smr-1.3.1 --gwas-summary {stats_path} --beqtl-summary /home/hammie/DATA/SMR/GTEx_V8_cis_eqtl_summary_lite/eQTL_besd_lite/{part} --out "{out_dir}/{disease}_expression_{part}_GTEx_SMR_allChrs" --bfile "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/additional_reference_data/1KG_and_refFlats/1kgenomes/EUR" --smr-multi'
        
        shell_do(cmd, make_part=True)
        #
        #
        ### END code amended from SMR() function definition above as at 2023-12-21 17:29GMT (HD).
        
    ### START Code temporarily(?) commented as at 2023-12-21 17:24GMT (HD).
    #
    #
    #f.close()
    #
    ## swarm command
    #cmd = f'swarm -b 15 -f .../omicSynth/v8/swarms/{disease}_gtex.SMR_swarm -g 48 -t 12 --logdir .../omicSynth/v8/swarms --module SMR'
    #
    #shell_do(cmd)
    #
    #
    ### END Code temporarily(?) commented as at 2023-12-21 17:24GMT (HD).

def SMR_psych(disease, stats_path, work_dir, out_dir):
    with open(f'.../omicSynth/v8/swarms/{disease}_psych.SMR_swarm', 'w') as f:
        f.write('module load SMR \n')
        f.write('\n')
        f.write('\n')
        f.write('# Single file per assay starts here. \n')
        f.write('\n')
        f.write('## expression_psychencode prefrontal cortex ## \n')
        f.write(f'smr --gwas-summary {stats_path} --beqtl-summary .../omicSynth/SMR_omics/eQTLs/PsychEncode/DER-08a_hg19_eQTL.significant --out {out_dir}/{disease}_expression_psychEncode_prefrontal_cortex_SMR_allChrs --bfile .../omicSynth/additional_reference_data/1KG_and_refFlats/1kgenomes/1kg_eur_1pct_ref_panel --smr-multi \n')
        f.write(' \n')
    
    # swarm command
    cmd = f'swarm -b 20 -f ...//omicSynth/v8/swarms/{disease}_psych.SMR_swarm -g 48 --logdir .../omicSynth/v8/swarms --time=12:00:00 --module SMR'
    
    shell_do(cmd)

def SMR_pQTL(disease, stats_path, work_dir, out_dir):
    with open(f'.../omicSynth/v8/swarms/{disease}_atlas.SMR_swarm', 'w') as f:
        f.write('module load SMR \n')
        f.write('\n')
        f.write('\n')
        f.write('# Single file per assay starts here. \n')
        f.write('\n')
        f.write('## pQTL CSF ## \n')
        f.write(f'smr --gwas-summary {stats_path} --beqtl-summary .../omicSynth/SMR_omics/pQTLs/atlas/csf_atlas_update --out {out_dir}/{disease}_pQTL_csf_SMR_allChrs --bfile .../additional_reference_data/1KG_and_refFlats/1kgenomes/1kg_eur_1pct_ref_panel --smr-multi \n')
        f.write(' \n')
        f.write('## pQTL plasma ## \n')
        f.write(f'smr --gwas-summary {stats_path} --beqtl-summary .../omicSynth/SMR_omics/pQTLs/atlas/plasma_atlas_update --out {out_dir}/{disease}_pQTL_plasma_SMR_allChrs --bfile .../omicSynth/additional_reference_data/1KG_and_refFlats/1kgenomes/1kg_eur_1pct_ref_panel --smr-multi \n')
        f.write(' \n')
        f.write('## pQTL brain ## \n')
        f.write(f'smr --gwas-summary {stats_path} --beqtl-summary .../omicSynth/SMR_omics/pQTLs/atlas/brain_atlas_update --out {out_dir}/{disease}_pQTL_brain_SMR_allChrs --bfile .../omicSynth/additional_reference_data/1KG_and_refFlats/1kgenomes/1kg_eur_1pct_ref_panel --smr-multi \n')
        f.write(' \n')
    
    # swarm command
    cmd = f'swarm -b 20 -f .../omicSynth/v8/swarms/{disease}_atlas.SMR_swarm -g 48 --logdir .../omicSynth/v8/swarms --time=12:00:00 --module SMR'
    
    shell_do(cmd)

def SMR_eQTL(disease, stats_path, work_dir, out_dir):
    with open(f'.../omicSynth/v8/swarms/{disease}_multiancestry.SMR_swarm', 'w') as f:
        f.write('module load SMR \n')
        f.write('\n')
        f.write('\n')
        f.write('# Single file per assay starts here. \n')
        f.write('\n')
        f.write('## eQTL multi ancestry ## \n')
        f.write(f'smr --gwas-summary {stats_path} --beqtl-summary .../omicSynth/SMR_omics/eQTLs/multiancestry/multi_ancestry_eqtl --out {out_dir}/{disease}_eQTL_multiancestry_SMR_allChrs --bfile .../omicSynth/additional_reference_data/1KG_and_refFlats/1kgenomes/1kg_eur_1pct_ref_panel --smr-multi \n')
        f.write(' \n')

    # swarm command
    cmd = f'swarm -b 20 -f .../omicSynth/v8/swarms/{disease}_multiancestry.SMR_swarm -g 48 --logdir .../omicSynth/v8/swarms --time=12:00:00 --module SMR'
    
    shell_do(cmd)

def SMR_eqtlGen(disease, stats_path, work_dir, out_dir):
    ### For this function definition, try and do analogously as for SMR()'s and SMR_gtex()'s' definitions above: START Code temporarily(?) commented as at 2023-12-22 22:02GMT (HD).
    #
    #
    #
    #
    #with open(f'.../omicSynth/v8/swarms/{disease}_eqtlgen.SMR_swarm', 'w') as f:
    #
    #
    #
    #
    ### END Code temporarily(?) commented as at 2023-12-22 22:02GMT (HD).
    #
    #
    #
    ### START code copy--pasted from SMR() function definition above as at 2023-12-22 22:07GMT (HD)
    #
    #
    cmd = f'cd "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/v8/intermediate_results/"'
    
    shell_do(cmd, make_part=True)
    #
    #
    ### END code copy--pasted from SMR() function definition above as at 2023-12-22 22:07GMT (HD).
    #
    #
    #
    ### START Code temporarily(?) commented as at 2023-12-22 22:08GMT (HD).
    #
    #
    #
    #
    #f.write('module load SMR \n')
    #f.write('\n')
    #f.write('\n')
    #f.write('# Single file per assay starts here. \n')
    #f.write('\n')
    #f.write('## expression_blood_eQTLgen ## \n')
    #
    #
    #
    #
    ### END Code temporarily(?) commented as at 2023-12-22 22:08GMT (HD).
    #
    #
    #f.write(f'smr --gwas-summary {stats_path} --beqtl-summary {work_dir}/SMR_omics/eQTLs/eQTLgen/cis-eQTLs-full_eQTLGen_AF_incl_nr_formatted_20191212.new.txt_besd-dense --out {out_dir}/{disease}_expression_blood_eQTLgen_SMR_allChrs --bfile .../omicSynth/additional_reference_data/1KG_and_refFlats/1kgenomes/1kg_eur_1pct_ref_panel --smr-multi \n')   #<-- Commented this line as at 2023-12-22 21:49GMT (HD).
    #
    ### START 'new' code as at 2023-12-22 21:49GMT (HD).
    #
    #
    #
    cmd = f'PATH=$PATH:"/media/hammie/My Passport/SOFTWARE/smr-1.3.1-linux-x86_64"; smr-1.3.1 --gwas-summary {stats_path} --beqtl-summary "/media/hammie/My Passport/DATA/eQTLGen/cis-eQTLs-full_eQTLGen_AF_incl_nr_formatted_20191212.new.txt_besd-dense" --out "{out_dir}/{disease}_expression_blood_eQTLgen_SMR_allChrs" --bfile "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/additional_reference_data/1KG_and_refFlats/1kgenomes/EUR" --smr-multi'
    
    shell_do(cmd, make_part=True)
    #
    #
    #
    ### END 'new' code as at 2023-12-22 21:49GMT (HD).
        
    ### START Code temporarily(?) commented as at 2023-12-22 22:12GMT (HD).
    #    #
    #    #
    #    f.write(' \n')
    #    f.close()
    #
    ## swarm command
    #cmd = f'swarm -b 15 -f .../omicSynth/v8/swarms/{disease}_eqtlgen.SMR_swarm -g 48 -t 12 --logdir .../omicSynth/v8/swarms --module SMR'
    #
    #shell_do(cmd)
    #
    #
    ### END Code temporarily(?) commented as at 2023-12-22 22:12GMT (HD).

# %%
#v8_GTEx_path = '.../omicSynth/SMR_omics/eQTLs/GTEx_v8/eQTL_besd_lite/'   #<-- Commented this line as at 2023-11-23 20:17GMT (HD).
#
v8_GTEx_path = '/home/hammie/DATA/SMR/GTEx_V8_cis_eqtl_summary_lite/eQTL_besd_lite/'   #<-- This line 'new' code as at 2023-11-23 20:18GMT (HD).

# define remaining paths
#
#
#
#out_dir = '.../omicSynth/v8/intermediate_results'   #<-- Commented this line as at 2023-11-23 19:43GMT (HD).
#
out_dir = '/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/v8/intermediate_results'   #<-- This line 'new' code as at 2023-11-23 19:43GMT (HD).
#
#
# work_dir = '.../omicSynth'   #<-- Commented this line as at 2023-11-23 18:28GMT (HD).
#
work_dir = '/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis'   #<-- This line 'new' code as at 2023-11-23 19:27GMT (HD).

# %% [markdown]
# ## All Diseases

# %% [markdown]
# ### Data Prep

# %%
# pull all GTEx paths
gtex_raw = glob.glob(f'{v8_GTEx_path}/*') 

gtex_short = [] # list to hold gtex tissue names
for x in gtex_raw:
    short_dx = x.split('/')[-1].rsplit('.',1)[0] # strip path to obtain the tissue name
    if short_dx not in gtex_short:
        gtex_short.append(short_dx)

# %%
#dx_list = glob.glob('.../omicSynth/outcome_summary_stats/*.ma') # paths so we can list out names of diseases we have sum stats for   #<-- Commented this line as at 2023-12-19 19:04GMT (HD).
#
dx_list = glob.glob('/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/outcome_summary_stats/*.ma') # paths so we can list out names of diseases we have sum stats for   #<-- This line 'new' code as at 2023-12-19 19:05GMT (HD).
#Note that as at 2023-12-21 16:55GMT (HD), according to Nautilus as on the Brutus this "Folder" (i.e., "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/outcome_summary_stats") "is Empty" so it doesn't contain any *.ma files actually
#
#
dx_clean = [] 
for x in dx_list:
    if 'metaBrain' not in x:
        dx_clean.append(x.split('/')[-1].rsplit('.')[0]) # strip for disease name
dx_clean.sort() # sort list of diseases in alphabetical order
dx_sum = dx_clean[1:] # cut off AD since we have different stats to use
dx_sum38 = dx_sum.copy()
#dx_sum.remove('LBD') # remove LBD to use different stats   #<-- TEMPorarily(?) commented this line as at 2023-11-24 23:01GMT (HD) as execution was giving an error:
#====
#---------------------------------------------------------------------------
#ValueError                                Traceback (most recent call last)
#Input In [8], in <cell line: 9>()
#      7 dx_sum = dx_clean[1:] # cut off AD since we have different stats to use
#      8 dx_sum38 = dx_sum.copy()
#----> 9 dx_sum.remove('LBD') # remove LBD to use different stats
#     10 dx_sum.remove('FTDold')
#
#ValueError: list.remove(x): x not in list
#====
#dx_sum.remove('FTDold') # remove old FTD sum stats   #<-- TEMPorarily(?) commented this line as at 2023-11-24 23:03GMT (HD)

# %%
# sumstats gr37
#
#
#
#sumstats_pd = '/home/hammie/DATA/nalls2019_no23AndMe-20221121T130807Z-001/nalls2019_no23AndMe/nallsEtAl2019_excluding23andMe_allVariants.tab.zip'   #<-- This line 'new' code as at 2023-11-24 22:55GMT (HD) -- as at present I'm aware that for actual operationalization of this code, we'd most probably need to unzip the linked file first indeed. #Commented this line as at 2023-12-11 15:58GMT (HD).
#
#sumstats_pd = '"/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/pd_smr/nallsEtAl2019_excluding23andMe_allVariants_mygwasDOTmaFormatFieldsOnly.tab"'   #<-- This line 'new' code as at 2023-12-11 15:58GMT (HD) -- as at present I'm aware that for actual operationalization of this code, we'd most probably need to unzip the linked file first indeed -- also, keep fields as in "https://yanglab.westlake.edu.cn/software/smr/#SMR" example "mygwas.ma" only. Also, note that (as per "https://yanglab.westlake.edu.cn/software/smr/#SMR") "The headers are not keywords and will be omitted by the program". #Commented this line as at 2023-12-21 12:24GMT (HD).
#
sumstats_pd = '"/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/pd_smr/nallsEtAl2019_excluding23andMe_allVariantsASrsIDs_mygwasDOTmaFormatFieldsOnly.tab"'   #<-- This line 'new' code as at 2023-12-11 15:58GMT (HD) -- as at present I'm aware that for actual operationalization of this code, we'd most probably need to unzip the linked file first indeed -- also, keep fields as in "https://yanglab.westlake.edu.cn/software/smr/#SMR" example "mygwas.ma" only. Also, note that (as per "https://yanglab.westlake.edu.cn/software/smr/#SMR") "The headers are not keywords and will be omitted by the program". #<-- This line 'new' code as at 2023-12-21 12:26GMT (HD).
#
#
### START Code TEMPorarily(?) commented as at 2023-11-24 23:04GMT (HD).
#
#sumstats_ad = '.../omicSynth/intermediate_results_AD_bellenguez/AD_hg19_smr.txt'
#sumstats_bd = '.../omicSynth/intermediate_results_BD_schiz/BDI_hg19_smr.txt'
#sumstats_lbd = '.../omicSynth/lbd_smr/LBD_37.ma'
#
### END Code TEMPorarily(?) commented as at 2023-11-24 23:04GMT (HD).
#
#
sumstats = []
for x in dx_sum:
    sumstats.append(glob.glob(f'.../omicSynth/outcome_summary_stats/{x}.ma')[0])

# %%
# sumstats gr38
#
#
#
### START Code TEMPorarily(?) commented as at 2023-11-24 23:06GMT (HD).
#
#sumstats_meta_ad = '.../omicSynth/intermediate_results_AD_bellenguez/AD_metabrain_version_smr.txt'
#sumstats_meta_bd = '.../omicSynth/intermediate_results_BD_schiz/BDI_hg38_smr.txt'
#
### END Code TEMPorarily(?) commented as at 2023-11-24 23:06GMT (HD).
#
#
sumstats_meta = []
for x in dx_sum38:
    sumstats_meta.append(glob.glob(f'.../omicSynth/outcome_summary_stats/{x}_metaBrain_gr38_edition.ma')[0])

# %% [markdown]
# ### GR37 Runs

# %%
# define remaining paths
#
#
#out_dir = '.../omicSynth/v8/inter_test'   #<-- Commented this line as at 2023-11-24 23:13GMT (HD).
#
#
out_dir = '/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/v8/inter_test'   #<-- This line 'new' code as at 2023-11-24 23:15GMT (HD). #Commented this line as at 2023-12-21 11:17GMT (HD), as in OS Terminal as on Brutus I got the following Error: #... -- and uncommented this line again as at 2023-12-21 11:48GMT (HD).
#====
#(base) hammie@hammie-Default-string:/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/pd_smr$ smr-1.3.1 --gwas-summary \"/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/pd_smr/nallsEtAl2019_excluding23andMe_allVariants_mygwasDOTmaFormatFieldsOnly.tab\" --beqtl-summary /home/hammie/DATA/SMR/BrainMeta_cis_eqtl_summary/BrainMeta_cis_eQTL_chr22 --ld-upper-limit --out /media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/v8/inter_test/PD_expression_brain_eMeta_SMR_chr22 --bfile \"/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/additional_reference_data/1KG_and_refFlats/1kgenomes/EUR\"
#*******************************************************************
#* Summary-data-based Mendelian Randomization (SMR)
#* Version 1.3.1
#* Build at Sep 21 2022 12:13:19, by GCC 8.3
#* (C) 2015 Futao Zhang, Zhihong Zhu and Jian Yang
#* The University of Queensland
#* MIT License
#*******************************************************************
#Analysis started: 11:9:18,Thu Dec 21,2023
#
#Options:
#--gwas-summary "/media/hammie/My
#
#Error: can not open the file ["/media/hammie/My] to read.
#
#Analysis completed: 11:9:18,Thu Dec 21,2023
#Computational time: 0:0:0
#(base) hammie@hammie-Default-string:/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/pd_smr$ pwd
#/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/pd_smr
#(base) hammie@hammie-Default-string:/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/pd_smr$
#====
#
#out_dir = '"/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/v8/inter_test"'   #<-- This line 'new' code as at 2023-12-21 11:17GMT (HD). #Commented this line as at 2023-12-21 11:47GMT (HD).

# %%
# run SMR process for AD and BD seperate due to different summary stat paths
#
#
SMR('PD',sumstats_pd, work_dir, out_dir)   #<-- This line 'new' code as at 2023-11-24 23:08GMT (HD)
#
#
### START Code temporarily(?) commented as at 2023-12-08 15:15GMT (HD), to allow execution of "run cell" (i.e., "Ctrl-Enter") for the code line directly above within this same cell
#
#SMR('AD',sumstats_ad, work_dir, out_dir)
#SMR('BD',sumstats_bd, work_dir, out_dir)
#SMR('LBD',sumstats_lbd, work_dir, out_dir)
#
### END Code temporarily(?) commented as at 2023-12-08 15:15GMT (HD)

#~--> As at 2023-12-08 15:24GMT (HD) led to "error":
#
#====
#Executing: swarm -b 15 -f "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/v8/swarms/PD.SMR_swarm" -g 48 -t 12 --logdir "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/v8/swarms" --module SMR
#
#---------------------------------------------------------------------------
#FileNotFoundError                         Traceback (most recent call last)
#Input In [19], in <cell line: 4>()
#      1 # run SMR process for AD and BD seperate due to different summary stat paths
#      2 #
#      3 #
#----> 4 SMR('PD',sumstats_pd, work_dir, out_dir)
#
#Input In [12], in SMR(disease, stats_path, work_dir, out_dir)
#     43 # swarm command
#     44 #cmd = f'swarm -b 15 -f .../omicSynth/v8/swarms/{disease}.SMR_swarm -g 48 -t 12 --logdir .../omicSynth/v8/swarms --module SMR'   #<-- Commented this line as at 2023-11-23 20:49GMT (HD).
#     45 #
#     46 cmd = f'swarm -b 15 -f "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/v8/swarms/{disease}.SMR_swarm" -g 48 -t 12 --logdir "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/v8/swarms" --module SMR'   #<-- This line 'new' code as at 2023-11-23 20:49GMT (HD).
#---> 48 shell_do(cmd)
#
#Input In [11], in shell_do(command, log, return_log, make_part)
#      2 print(f'Executing: {(" ").join(command.split())}', file=sys.stderr)
#      4 if make_part == False:
#----> 5     res = subprocess.run(command.split(), stdout=subprocess.PIPE)
#      6 else:
#      7     res = subprocess.run(command, shell=True, stdout=subprocess.PIPE)
#
#File ~/anaconda3/lib/python3.9/subprocess.py:505, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#    502     kwargs['stdout'] = PIPE
#    503     kwargs['stderr'] = PIPE
#--> 505 with Popen(*popenargs, **kwargs) as process:
#    506     try:
#    507         stdout, stderr = process.communicate(input, timeout=timeout)
#
#File ~/anaconda3/lib/python3.9/subprocess.py:951, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask)
#    947         if self.text_mode:
#    948             self.stderr = io.TextIOWrapper(self.stderr,
#    949                     encoding=encoding, errors=errors)
#--> 951     self._execute_child(args, executable, preexec_fn, close_fds,
#    952                         pass_fds, cwd, env,
#    953                         startupinfo, creationflags, shell,
#    954                         p2cread, p2cwrite,
#    955                         c2pread, c2pwrite,
#    956                         errread, errwrite,
#    957                         restore_signals,
#    958                         gid, gids, uid, umask,
#    959                         start_new_session)
#    960 except:
#    961     # Cleanup if the child failed starting.
#    962     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
#File ~/anaconda3/lib/python3.9/subprocess.py:1821, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session)
#   1819     if errno_num != 0:
#   1820         err_msg = os.strerror(errno_num)
#-> 1821     raise child_exception_type(errno_num, err_msg, err_filename)
#   1822 raise child_exception_type(err_msg)
#
#FileNotFoundError: [Errno 2] No such file or directory: 'swarm'
#====

#As at 2023-12-21 16:47GMT (HD) gave as screen output:
#====
#Executing: cd "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/v8/intermediate_results/"
#Executing: PATH=$PATH:"/media/hammie/My Passport/SOFTWARE/smr-1.3.1-linux-x86_64"; smr-1.3.1 --gwas-summary "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/pd_smr/nallsEtAl2019_excluding23andMe_allVariantsASrsIDs_mygwasDOTmaFormatFieldsOnly.tab" --beqtl-summary /home/hammie/DATA/SMR/BrainMeta_cis_eqtl_summary/BrainMeta_cis_eQTL_chr1 --out "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/v8/inter_test/PD_expression_brain_eMeta_SMR_chr1" --bfile "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/additional_reference_data/1KG_and_refFlats/1kgenomes/EUR" --smr-multi
#Executing: PATH=$PATH:"/media/hammie/My Passport/SOFTWARE/smr-1.3.1-linux-x86_64"; smr-1.3.1 --gwas-summary "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/pd_smr/nallsEtAl2019_excluding23andMe_allVariantsASrsIDs_mygwasDOTmaFormatFieldsOnly.tab" --beqtl-summary /home/hammie/DATA/SMR/BrainMeta_cis_eqtl_summary/BrainMeta_cis_eQTL_chr2 --out "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/v8/inter_test/PD_expression_brain_eMeta_SMR_chr2" --bfile "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/additional_reference_data/1KG_and_refFlats/1kgenomes/EUR" --smr-multi
#Executing: PATH=$PATH:"/media/hammie/My Passport/SOFTWARE/smr-1.3.1-linux-x86_64"; smr-1.3.1 --gwas-summary "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/pd_smr/nallsEtAl2019_excluding23andMe_allVariantsASrsIDs_mygwasDOTmaFormatFieldsOnly.tab" --beqtl-summary /home/hammie/DATA/SMR/BrainMeta_cis_eqtl_summary/BrainMeta_cis_eQTL_chr3 --out "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/v8/inter_test/PD_expression_brain_eMeta_SMR_chr3" --bfile "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/additional_reference_data/1KG_and_refFlats/1kgenomes/EUR" --smr-multi
#Executing: PATH=$PATH:"/media/hammie/My Passport/SOFTWARE/smr-1.3.1-linux-x86_64"; smr-1.3.1 --gwas-summary "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/pd_smr/nallsEtAl2019_excluding23andMe_allVariantsASrsIDs_mygwasDOTmaFormatFieldsOnly.tab" --beqtl-summary /home/hammie/DATA/SMR/BrainMeta_cis_eqtl_summary/BrainMeta_cis_eQTL_chr4 --out "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/v8/inter_test/PD_expression_brain_eMeta_SMR_chr4" --bfile "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/additional_reference_data/1KG_and_refFlats/1kgenomes/EUR" --smr-multi
#Executing: PATH=$PATH:"/media/hammie/My Passport/SOFTWARE/smr-1.3.1-linux-x86_64"; smr-1.3.1 --gwas-summary "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/pd_smr/nallsEtAl2019_excluding23andMe_allVariantsASrsIDs_mygwasDOTmaFormatFieldsOnly.tab" --beqtl-summary /home/hammie/DATA/SMR/BrainMeta_cis_eqtl_summary/BrainMeta_cis_eQTL_chr5 --out "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/v8/inter_test/PD_expression_brain_eMeta_SMR_chr5" --bfile "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/additional_reference_data/1KG_and_refFlats/1kgenomes/EUR" --smr-multi
#Executing: PATH=$PATH:"/media/hammie/My Passport/SOFTWARE/smr-1.3.1-linux-x86_64"; smr-1.3.1 --gwas-summary "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/pd_smr/nallsEtAl2019_excluding23andMe_allVariantsASrsIDs_mygwasDOTmaFormatFieldsOnly.tab" --beqtl-summary /home/hammie/DATA/SMR/BrainMeta_cis_eqtl_summary/BrainMeta_cis_eQTL_chr6 --out "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/v8/inter_test/PD_expression_brain_eMeta_SMR_chr6" --bfile "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/additional_reference_data/1KG_and_refFlats/1kgenomes/EUR" --smr-multi
#Executing: PATH=$PATH:"/media/hammie/My Passport/SOFTWARE/smr-1.3.1-linux-x86_64"; smr-1.3.1 --gwas-summary "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/pd_smr/nallsEtAl2019_excluding23andMe_allVariantsASrsIDs_mygwasDOTmaFormatFieldsOnly.tab" --beqtl-summary /home/hammie/DATA/SMR/BrainMeta_cis_eqtl_summary/BrainMeta_cis_eQTL_chr7 --out "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/v8/inter_test/PD_expression_brain_eMeta_SMR_chr7" --bfile "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/additional_reference_data/1KG_and_refFlats/1kgenomes/EUR" --smr-multi
#Executing: PATH=$PATH:"/media/hammie/My Passport/SOFTWARE/smr-1.3.1-linux-x86_64"; smr-1.3.1 --gwas-summary "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/pd_smr/nallsEtAl2019_excluding23andMe_allVariantsASrsIDs_mygwasDOTmaFormatFieldsOnly.tab" --beqtl-summary /home/hammie/DATA/SMR/BrainMeta_cis_eqtl_summary/BrainMeta_cis_eQTL_chr8 --out "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/v8/inter_test/PD_expression_brain_eMeta_SMR_chr8" --bfile "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/additional_reference_data/1KG_and_refFlats/1kgenomes/EUR" --smr-multi
#Executing: PATH=$PATH:"/media/hammie/My Passport/SOFTWARE/smr-1.3.1-linux-x86_64"; smr-1.3.1 --gwas-summary "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/pd_smr/nallsEtAl2019_excluding23andMe_allVariantsASrsIDs_mygwasDOTmaFormatFieldsOnly.tab" --beqtl-summary /home/hammie/DATA/SMR/BrainMeta_cis_eqtl_summary/BrainMeta_cis_eQTL_chr9 --out "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/v8/inter_test/PD_expression_brain_eMeta_SMR_chr9" --bfile "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/additional_reference_data/1KG_and_refFlats/1kgenomes/EUR" --smr-multi
#Executing: PATH=$PATH:"/media/hammie/My Passport/SOFTWARE/smr-1.3.1-linux-x86_64"; smr-1.3.1 --gwas-summary "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/pd_smr/nallsEtAl2019_excluding23andMe_allVariantsASrsIDs_mygwasDOTmaFormatFieldsOnly.tab" --beqtl-summary /home/hammie/DATA/SMR/BrainMeta_cis_eqtl_summary/BrainMeta_cis_eQTL_chr10 --out "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/v8/inter_test/PD_expression_brain_eMeta_SMR_chr10" --bfile "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/additional_reference_data/1KG_and_refFlats/1kgenomes/EUR" --smr-multi
#Executing: PATH=$PATH:"/media/hammie/My Passport/SOFTWARE/smr-1.3.1-linux-x86_64"; smr-1.3.1 --gwas-summary "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/pd_smr/nallsEtAl2019_excluding23andMe_allVariantsASrsIDs_mygwasDOTmaFormatFieldsOnly.tab" --beqtl-summary /home/hammie/DATA/SMR/BrainMeta_cis_eqtl_summary/BrainMeta_cis_eQTL_chr11 --out "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/v8/inter_test/PD_expression_brain_eMeta_SMR_chr11" --bfile "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/additional_reference_data/1KG_and_refFlats/1kgenomes/EUR" --smr-multi
#Executing: PATH=$PATH:"/media/hammie/My Passport/SOFTWARE/smr-1.3.1-linux-x86_64"; smr-1.3.1 --gwas-summary "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/pd_smr/nallsEtAl2019_excluding23andMe_allVariantsASrsIDs_mygwasDOTmaFormatFieldsOnly.tab" --beqtl-summary /home/hammie/DATA/SMR/BrainMeta_cis_eqtl_summary/BrainMeta_cis_eQTL_chr12 --out "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/v8/inter_test/PD_expression_brain_eMeta_SMR_chr12" --bfile "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/additional_reference_data/1KG_and_refFlats/1kgenomes/EUR" --smr-multi
#Executing: PATH=$PATH:"/media/hammie/My Passport/SOFTWARE/smr-1.3.1-linux-x86_64"; smr-1.3.1 --gwas-summary "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/pd_smr/nallsEtAl2019_excluding23andMe_allVariantsASrsIDs_mygwasDOTmaFormatFieldsOnly.tab" --beqtl-summary /home/hammie/DATA/SMR/BrainMeta_cis_eqtl_summary/BrainMeta_cis_eQTL_chr13 --out "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/v8/inter_test/PD_expression_brain_eMeta_SMR_chr13" --bfile "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/additional_reference_data/1KG_and_refFlats/1kgenomes/EUR" --smr-multi
#Executing: PATH=$PATH:"/media/hammie/My Passport/SOFTWARE/smr-1.3.1-linux-x86_64"; smr-1.3.1 --gwas-summary "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/pd_smr/nallsEtAl2019_excluding23andMe_allVariantsASrsIDs_mygwasDOTmaFormatFieldsOnly.tab" --beqtl-summary /home/hammie/DATA/SMR/BrainMeta_cis_eqtl_summary/BrainMeta_cis_eQTL_chr14 --out "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/v8/inter_test/PD_expression_brain_eMeta_SMR_chr14" --bfile "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/additional_reference_data/1KG_and_refFlats/1kgenomes/EUR" --smr-multi
#
#Executing: PATH=$PATH:"/media/hammie/My Passport/SOFTWARE/smr-1.3.1-linux-x86_64"; smr-1.3.1 --gwas-summary "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/pd_smr/nallsEtAl2019_excluding23andMe_allVariantsASrsIDs_mygwasDOTmaFormatFieldsOnly.tab" --beqtl-summary /home/hammie/DATA/SMR/BrainMeta_cis_eqtl_summary/BrainMeta_cis_eQTL_chr15 --out "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/v8/inter_test/PD_expression_brain_eMeta_SMR_chr15" --bfile "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/additional_reference_data/1KG_and_refFlats/1kgenomes/EUR" --smr-multi
#Executing: PATH=$PATH:"/media/hammie/My Passport/SOFTWARE/smr-1.3.1-linux-x86_64"; smr-1.3.1 --gwas-summary "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/pd_smr/nallsEtAl2019_excluding23andMe_allVariantsASrsIDs_mygwasDOTmaFormatFieldsOnly.tab" --beqtl-summary /home/hammie/DATA/SMR/BrainMeta_cis_eqtl_summary/BrainMeta_cis_eQTL_chr16 --out "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/v8/inter_test/PD_expression_brain_eMeta_SMR_chr16" --bfile "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/additional_reference_data/1KG_and_refFlats/1kgenomes/EUR" --smr-multi
#Executing: PATH=$PATH:"/media/hammie/My Passport/SOFTWARE/smr-1.3.1-linux-x86_64"; smr-1.3.1 --gwas-summary "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/pd_smr/nallsEtAl2019_excluding23andMe_allVariantsASrsIDs_mygwasDOTmaFormatFieldsOnly.tab" --beqtl-summary /home/hammie/DATA/SMR/BrainMeta_cis_eqtl_summary/BrainMeta_cis_eQTL_chr17 --out "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/v8/inter_test/PD_expression_brain_eMeta_SMR_chr17" --bfile "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/additional_reference_data/1KG_and_refFlats/1kgenomes/EUR" --smr-multi
#Executing: PATH=$PATH:"/media/hammie/My Passport/SOFTWARE/smr-1.3.1-linux-x86_64"; smr-1.3.1 --gwas-summary "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/pd_smr/nallsEtAl2019_excluding23andMe_allVariantsASrsIDs_mygwasDOTmaFormatFieldsOnly.tab" --beqtl-summary /home/hammie/DATA/SMR/BrainMeta_cis_eqtl_summary/BrainMeta_cis_eQTL_chr18 --out "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/v8/inter_test/PD_expression_brain_eMeta_SMR_chr18" --bfile "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/additional_reference_data/1KG_and_refFlats/1kgenomes/EUR" --smr-multi
#Executing: PATH=$PATH:"/media/hammie/My Passport/SOFTWARE/smr-1.3.1-linux-x86_64"; smr-1.3.1 --gwas-summary "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/pd_smr/nallsEtAl2019_excluding23andMe_allVariantsASrsIDs_mygwasDOTmaFormatFieldsOnly.tab" --beqtl-summary /home/hammie/DATA/SMR/BrainMeta_cis_eqtl_summary/BrainMeta_cis_eQTL_chr19 --out "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/v8/inter_test/PD_expression_brain_eMeta_SMR_chr19" --bfile "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/additional_reference_data/1KG_and_refFlats/1kgenomes/EUR" --smr-multi
#Executing: PATH=$PATH:"/media/hammie/My Passport/SOFTWARE/smr-1.3.1-linux-x86_64"; smr-1.3.1 --gwas-summary "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/pd_smr/nallsEtAl2019_excluding23andMe_allVariantsASrsIDs_mygwasDOTmaFormatFieldsOnly.tab" --beqtl-summary /home/hammie/DATA/SMR/BrainMeta_cis_eqtl_summary/BrainMeta_cis_eQTL_chr20 --out "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/v8/inter_test/PD_expression_brain_eMeta_SMR_chr20" --bfile "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/additional_reference_data/1KG_and_refFlats/1kgenomes/EUR" --smr-multi
#Executing: PATH=$PATH:"/media/hammie/My Passport/SOFTWARE/smr-1.3.1-linux-x86_64"; smr-1.3.1 --gwas-summary "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/pd_smr/nallsEtAl2019_excluding23andMe_allVariantsASrsIDs_mygwasDOTmaFormatFieldsOnly.tab" --beqtl-summary /home/hammie/DATA/SMR/BrainMeta_cis_eqtl_summary/BrainMeta_cis_eQTL_chr21 --out "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/v8/inter_test/PD_expression_brain_eMeta_SMR_chr21" --bfile "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/additional_reference_data/1KG_and_refFlats/1kgenomes/EUR" --smr-multi
#Executing: PATH=$PATH:"/media/hammie/My Passport/SOFTWARE/smr-1.3.1-linux-x86_64"; smr-1.3.1 --gwas-summary "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/pd_smr/nallsEtAl2019_excluding23andMe_allVariantsASrsIDs_mygwasDOTmaFormatFieldsOnly.tab" --beqtl-summary /home/hammie/DATA/SMR/BrainMeta_cis_eqtl_summary/BrainMeta_cis_eQTL_chr22 --out "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/v8/inter_test/PD_expression_brain_eMeta_SMR_chr22" --bfile "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/additional_reference_data/1KG_and_refFlats/1kgenomes/EUR" --smr-multi
#====
# Out:
# Executing: cd "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/v8/intermediate_results/"
# Executing: PATH=$PATH:"/media/hammie/My Passport/SOFTWARE/smr-1.3.1-linux-x86_64"; smr-1.3.1 --gwas-summary "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/pd_smr/nallsEtAl2019_excluding23andMe_allVariantsASrsIDs_mygwasDOTmaFormatFieldsOnly.tab" --beqtl-summary /home/hammie/DATA/SMR/BrainMeta_cis_eqtl_summary/BrainMeta_cis_eQTL_chr22 --out "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/v8/inter_test/PD_expression_brain_eMeta_SMR_chr22" --bfile "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/additional_reference_data/1KG_and_refFlats/1kgenomes/EUR" --smr-multi

# %%
#SMR('FTD_pottier', '.../omicSynth/outcome_summary_stats/FTD_Pottier37.ma', work_dir, out_dir)   #<-- (Temporarily?) commented this line as at 2023-12-21 15:28GMT (HD).

# %%
### START Code (temporarily?) commented as at 2023-12-21 15:30GMT (HD).
#
## run for all other dx
#for dx, stat in zip(dx_sum, sumstats):
#    SMR(dx,stat, work_dir, out_dir)
#
### END Code (temporarily?) commented as at 2023-12-21 15:30GMT (HD).

# %%
### START Code (temporarily?) commented as at 2023-12-21 15:30GMT (HD) (exclude non-"PD" [Nalls et al., Lancet Neurol 2019] diseases in this first instance).
#
#
## run SMR process for AD and BD seperate due to different summary stat paths #<-- 'Commented out this comment line' as at 2023-12-21 17:01GMT (HD).
#
# Run SMR process for PD, AD and BD separately due to different summary stat paths #<-- This line 'new' comment as at 2023-12-21 17:02GMT (HD).
SMR_gtex('PD',sumstats_pd, work_dir, out_dir, gtex_short)   #<-- This line 'new' code as at 2023-12-21 17:04GMT (HD).
#
#SMR_gtex('AD',sumstats_ad, work_dir, out_dir, gtex_short)
#SMR_gtex('BD',sumstats_bd, work_dir, out_dir, gtex_short)
#
#
### END Code (temporarily?) commented as at 2023-12-21 15:30GMT (HD).
# Out:
# Executing: cd "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/v8/intermediate_results/"
# Executing: PATH=$PATH:"/media/hammie/My Passport/SOFTWARE/smr-1.3.1-linux-x86_64"; smr-1.3.1 --gwas-summary "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/pd_smr/nallsEtAl2019_excluding23andMe_allVariantsASrsIDs_mygwasDOTmaFormatFieldsOnly.tab" --beqtl-summary /home/hammie/DATA/SMR/GTEx_V8_cis_eqtl_summary_lite/eQTL_besd_lite/A --out "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/v8/inter_test/PD_expression_A_GTEx_SMR_allChrs" --bfile "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/additional_reference_data/1KG_and_refFlats/1kgenomes/EUR" --smr-multi
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [55], in <cell line: 9>()
# ...

# %%
### START Code (temporarily?) commented as at 2023-12-22 22:28GMT (HD): exclude non-"PD" (Nalls et al., Lancet Neurol 2019) diseases in this first instance.
#
## run for all other dx
#for dx, stat in zip(dx_sum, sumstats):
#    SMR_gtex(dx,stat, work_dir, out_dir, gtex_short)
#
### END Code (temporarily?) commented as at 2023-12-22 22:28GMT (HD).

# %%
#SMR_gtex('FTD_pottier', '.../omicSynth/outcome_summary_stats/FTD_Pottier37.ma', work_dir, out_dir, gtex_short)   #<-- (Temporarily?) commented this line as at 2023-12-21 15:37GMT (HD): exclude non-"PD" (Nalls et al., Lancet Neurol 2019) diseases in this first instance.

# %%
### START Code (temporarily?) commented as at 2023-12-21 15:38GMT (HD): Consider only eQTLGen & GTEx as exposures in the first instance.
#
## run SMR process for AD and BD seperate due to different summary stat paths
#SMR_psych('AD',sumstats_ad, work_dir, out_dir)
#SMR_psych('BD',sumstats_bd, work_dir, out_dir)
#
### END Code (temporarily?) commented as at 2023-12-21 15:38GMT (HD).

# %%
#SMR_psych('LBD',sumstats_lbd, work_dir, out_dir)   #(Temporarily?) commented this line as at 2023-12-21 16:03GMT (HD): Consider only eQTLGen & GTEx as exposures in the first instance.

# %%
#SMR_psych('PSP', sumstats[-4], work_dir, out_dir)   #(Temporarily?) commented this line as at 2023-12-21 16:03GMT (HD): Consider only eQTLGen & GTEx as exposures in the first instance.

# %%
#SMR_psych('FTD_pottier', '.../omicSynth/outcome_summary_stats/FTD_Pottier37.ma', work_dir, out_dir)   #(Temporarily?) commented this line as at 2023-12-21 16:03GMT (HD): Consider only eQTLGen & GTEx as exposures in the first instance.

# %%
### START Code (temporarily?) commented as at 2023-12-21 16:04GMT (HD): Consider only eQTLGen & GTEx as exposures in the first instance.
#
# run for all other dx
#for dx, stat in zip(dx_sum, sumstats):
#    SMR_psych(dx,stat, work_dir, out_dir)
#
### END Code (temporarily?) commented as at 2023-12-21 16:04GMT (HD).

# %%
### START Code (temporarily?) commented as at 2023-12-21 16:05GMT (HD): Consider only eQTLGen & GTEx as exposures in the first instance.
#
## run SMR process for AD and BD seperate due to different summary stat paths
#SMR_pQTL('AD',sumstats_ad, work_dir, out_dir)
#SMR_pQTL('BD',sumstats_bd, work_dir, out_dir)
#SMR_pQTL('LBD',sumstats_lbd, work_dir, out_dir)
#
### END Code (temporarily?) commented as at 2023-12-21 16:05GMT (HD).

# %%
### START Code (temporarily?) commented as at 2023-12-21 16:07GMT (HD): Consider only eQTLGen & GTEx as exposures in the first instance.
#
#SMR_pQTL('PSP', sumstats[-4], work_dir, out_dir)
#
#SMR_pQTL('FT2', '.../omicSynth/outcome_summary_stats/FTD_Pottier37.ma', work_dir, out_dir)
#
### END Code (temporarily?) commented as at 2023-12-21 16:07GMT (HD).

# %%
### START Code (temporarily?) commented as at 2023-12-21 16:07GMT (HD): Consider only eQTLGen & GTEx as exposures in the first instance.
#
## run for all other dx
#for dx, stat in zip(dx_sum, sumstats):
#    SMR_pQTL(dx,stat, work_dir, out_dir)
#
### END Code (temporarily?) commented as at 2023-12-21 16:07GMT (HD).

# %%
### START Code (temporarily?) commented as at 2023-12-21 16:08GMT (HD): Consider only eQTLGen & GTEx as exposures in the first instance.
#
## run SMR process for AD and BD seperate due to different summary stat paths
#SMR_eQTL('AD',sumstats_ad, work_dir, out_dir)
#SMR_eQTL('BD',sumstats_bd, work_dir, out_dir)
#SMR_eQTL('LBD',sumstats_lbd, work_dir, out_dir)
#
### END Code (temporarily?) commented as at 2023-12-21 16:08GMT (HD).

# %%
#SMR_eQTL('FTD_pottier', '.../omicSynth/outcome_summary_stats/FTD_Pottier37.ma', work_dir, out_dir)   #(Temporarily?) commented this line as at 2023-12-21 16:09GMT (HD): Consider only eQTLGen & GTEx as exposures in the first instance.

# %%
### START Code (temporarily?) commented as at 2023-12-21 16:09GMT (HD): Consider only eQTLGen & GTEx as exposures in the first instance.
#
## run for all other dx
#for dx, stat in zip(dx_sum, sumstats):
#    SMR_eQTL(dx,stat, work_dir, out_dir)
#
### END Code (temporarily?) commented as at 2023-12-21 16:09GMT (HD)

# %%
### START Code (temporarily?) commented as at 2023-12-22 22:35GMT (HD): exclude non-"PD" (Nalls et al., Lancet Neurol 2019) diseases in this first instance.
#
#
## run SMR process for AD and BD seperate due to different summary stat paths #<-- 'Commented out this comment line' as at 2023-12-22 22:37GMT (HD).
#
# Run SMR process for AD; BD; LBD; and PD separately due to different summary stat paths #<-- This line 'new' comment as at 2023-12-22 22:38GMT (HD).
#SMR_eqtlGen('AD',sumstats_ad, work_dir, out_dir)
#SMR_eqtlGen('BD',sumstats_bd, work_dir, out_dir)
#SMR_eqtlGen('LBD',sumstats_lbd, work_dir, out_dir)
#
SMR_eqtlGen('PD',sumstats_pd, work_dir, out_dir)   #<-- This line 'new' code as at 2023-12-22 22:36GMT (HD).
#--> As at 2023-12-22 22:54GMT (HD) this yielded the following screen output here:
#====
#Executing: cd "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/v8/intermediate_results/"
#Executing: PATH=$PATH:"/media/hammie/My Passport/SOFTWARE/smr-1.3.1-linux-x86_64"; smr-1.3.1 --gwas-summary "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/pd_smr/nallsEtAl2019_excluding23andMe_allVariantsASrsIDs_mygwasDOTmaFormatFieldsOnly.tab" --beqtl-summary "/media/hammie/My Passport/DATA/eQTLGen/cis-eQTLs-full_eQTLGen_AF_incl_nr_formatted_20191212.new.txt_besd-dense" --out "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/v8/inter_test/PD_expression_blood_eQTLgen_SMR_allChrs" --bfile "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/additional_reference_data/1KG_and_refFlats/1kgenomes/EUR" --smr-multi
#====
#
#
### END Code (temporarily?) commented as at 2023-12-22 22:35GMT (HD).
# Out:
# Executing: cd "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/v8/intermediate_results/"
# Executing: PATH=$PATH:"/media/hammie/My Passport/SOFTWARE/smr-1.3.1-linux-x86_64"; smr-1.3.1 --gwas-summary "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/pd_smr/nallsEtAl2019_excluding23andMe_allVariantsASrsIDs_mygwasDOTmaFormatFieldsOnly.tab" --beqtl-summary "/media/hammie/My Passport/DATA/eQTLGen/cis-eQTLs-full_eQTLGen_AF_incl_nr_formatted_20191212.new.txt_besd-dense" --out "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/v8/inter_test/PD_expression_blood_eQTLgen_SMR_allChrs" --bfile "/media/hammie/My Passport/SOFTWARE/omicsynthcustomanalysis/additional_reference_data/1KG_and_refFlats/1kgenomes/EUR" --smr-multi

# %%
### START Code (temporarily?) commented as at 2023-12-22 22:38GMT (HD): exclude non-"PD" (Nalls et al., Lancet Neurol 2019) diseases in this first instance.
#
## run for all other dx
#for dx, stat in zip(dx_sum, sumstats):
#    SMR_eqtlGen(dx,stat, work_dir, out_dir)
#
### END Code (temporarily?) commented as at 2023-12-22 22:38GMT (HD)

# %% [markdown]
# ### MetaBrain GR38 Runs

# %%
#"meta" as for/with "metaBrain" data indeed -- REF SMR_meta() function definition above as at 2023-12-21 16:13GMT.

### START Code (temporarily?) commented as at 2023-12-21 16:14GMT (HD): Consider only eQTLGen & GTEx as exposures in the first instance.
#
## run SMR process for AD and BD seperate due to different summary stat paths
#SMR_meta('AD',sumstats_meta_ad, work_dir, out_dir)
#SMR_meta('BD',sumstats_meta_bd, work_dir, out_dir)
#
### END Code (temporarily?) commented as at 2023-12-21 16:14GMT (HD)

# %%
#SMR_meta('FTD_pottier', '.../omicSynth/outcome_summary_stats/FTD_Pottier37_metaBrain_gr38_edition.ma', work_dir, out_dir)   #(Temporarily?) commented this line as at 2023-12-21 16:15GMT (HD): Consider only eQTLGen & GTEx as exposures in the first instance.

# %%
### START Code (temporarily?) commented as at 2023-12-21 16:16GMT (HD): Consider only eQTLGen & GTEx as exposures in the first instance.
#
## g38
#for dx, stat in zip(dx_sum, sumstats_meta):
#    SMR_meta(dx,stat, work_dir, out_dir)
#
### END Code (temporarily?) commented as at 2023-12-21 16:16GMT (HD)
